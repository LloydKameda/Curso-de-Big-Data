# %% [markdown]
# # Etapa 3: Análisis de datos utilizando SQL

# %% [markdown]
# ## Objetivos
#
# En esta práctica subiremos los datos a una base de datos SQL y realizaremos diferentes queries para obtener información sobre los datos

# %%
import pandas as pd
import numpy as np
# !pip install PyMySQL --quiet
import pymysql as pymsql
# !pip install mysql-connector --quiet
import mysql.connector
from sqlalchemy import create_engine
# !pip install sqlalchemy-utils --quiet
from sqlalchemy_utils import database_exists, create_database
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 674.8 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 15.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for mysql-connector (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 KB 3.5 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta = '/content/drive/MyDrive/Colab Notebooks/dataset_part_2.csv' 

dataset_part_2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset_part_2.csv')

# %% [markdown]
# ### Tarea 1: Subir los datos a la base de datos:

# %% [markdown]
# Primero cargamos el archivo de datos `dataset_part_2.csv`.

# %%
df_path = "dataset_part_2.csv"
dataset_part_2 = pd.read_csv(df_path)

# %%
#Rellena la siguiente variable con tu nombre y apellido (Todo junto y sin espacios). 
nombreBD = 'CarlosRosadoRodriguez'
linkConexion = 'mysql+mysqlconnector://alumno:385bd4cf713a8a36@13.39.109.107/' + nombreBD
#Establecemos la conexión 
engine = create_engine(linkConexion)

# %%
if not database_exists(engine.url):
    create_database(engine.url)

# %%
# Añadir el dataframe a sql SPACEXTBL usando la función to_sql().


dataset_part_2.to_sql('SPACEXTBL', con = engine , if_exists = "replace")
dataset_part_2
# Out:
#     FlightNumber        Date BoosterVersion   PayloadMass  \
# 0              1  2010-06-04       Falcon 9   6123.547647
# 1              2  2012-05-22       Falcon 9    525.000000
# 2              3  2013-03-01       Falcon 9    677.000000
# 3              4  2013-09-29       Falcon 9    500.000000
# 4              5  2013-12-03       Falcon 9   3170.000000
# ..           ...         ...            ...           ...
# 85            86  2020-09-03       Falcon 9  15600.000000
# 86            87  2020-10-06       Falcon 9  15600.000000
# 87            88  2020-10-18       Falcon 9  15600.000000
# 88            89  2020-10-24       Falcon 9  15600.000000
# 89            90  2020-11-05       Falcon 9   3681.000000
#
#                       Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0   Dragon Qualification Unit   LEO  CCSFS SLC 40      None None        1
# 1          COTS Demo Flight 2   LEO  CCSFS SLC 40      None None        1
# 2                       CRS-2   ISS  CCSFS SLC 40      None None        1
# 3                    CASSIOPE    PO   VAFB SLC 4E    False Ocean        1
# 4                       SES-8   GTO  CCSFS SLC 40      None None        1
# ..                        ...   ...           ...            ...      ...
# 85                Starlink-11  VLEO    KSC LC 39A      True ASDS        2
# 86                Starlink-12  VLEO    KSC LC 39A      True ASDS        3
# 87                Starlink-13  VLEO    KSC LC 39A      True ASDS        6
# 88                Starlink-14  VLEO  CCSFS SLC 40      True ASDS        3
# 89   GPS III SV04 (Sacagawea)   MEO  CCSFS SLC 40      True ASDS        1
#
#     GridFins  Reused   Legs                LandingPad  Block  \
# 0      False   False  False                       NaN    1.0
# 1      False   False  False                       NaN    1.0
# 2      False   False  False                       NaN    1.0
# 3      False   False  False                       NaN    1.0
# 4      False   False  False                       NaN    1.0
# ..       ...     ...    ...                       ...    ...
# 85      True    True   True  5e9e3032383ecb6bb234e7ca    5.0
# 86      True    True   True  5e9e3032383ecb6bb234e7ca    5.0
# 87      True    True   True  5e9e3032383ecb6bb234e7ca    5.0
# 88      True    True   True  5e9e3033383ecbb9e534e7cc    5.0
# 89      True   False   True  5e9e3032383ecb6bb234e7ca    5.0
#
#                     Customers  Mission_Outcome  ReusedCount Serial  \
# 0                      SpaceX             True            0  B0003
# 1                  NASA(COTS)             True            0  B0005
# 2                  NASA (CRS)             True            0  B0007
# 3                         MDA             True            0  B1003
# 4                         SES             True            0  B1004
# ..                        ...              ...          ...    ...
# 85                     SpaceX             True           12  B1060
# 86                     SpaceX             True           13  B1058
# 87                     SpaceX             True           12  B1051
# 88                     SpaceX             True           12  B1060
# 89  United States Space Force             True            8  B1062
#
#      Longitude   Latitude  Class
# 0   -80.577366  28.561857      0
# 1   -80.577366  28.561857      0
# 2   -80.577366  28.561857      0
# 3  -120.610829  34.632093      0
# 4   -80.577366  28.561857      0
# ..         ...        ...    ...
# 85  -80.603956  28.608058      1
# 86  -80.603956  28.608058      1
# 87  -80.603956  28.608058      1
# 88  -80.577366  28.561857      1
# 89  -80.577366  28.561857      1
#
# [90 rows x 21 columns]

# %%
query = """select * from SPACEXTBL;"""
df  = pd.read_sql(query, con = engine )
df

# %%
query = """select * from SPACEXTBL;"""
df  = pd.read_sql(query, con = engine )
df

# %% [markdown]
# ## Tarea 2: Queries con SQL

# %% [markdown]
# ### Ejercicio 1
#
# ##### Muestra las diferentes plataformas de lanzamiento:

# %%
#Rellena la variable query con tu consulta
query = """select distinct LaunchSite from SPACEXTBL    """
df  = pd.read_sql(query, con = engine )
df
# Out:
#      LaunchSite
# 0  CCSFS SLC 40
# 1   VAFB SLC 4E
# 2    KSC LC 39A

# %%
query =

# %% [markdown]
# ### Ejercicio 2
#
# ##### Muestra 5 lanzamientos cuya plataforma empiece por 'CCS'

# %%
query = """select LaunchSite 

from SPACEXTBL 
where LaunchSite like 'CCS%'
limit 5   """
df  = pd.read_sql(query, con = engine )
df
# Out:
#      LaunchSite
# 0  CCSFS SLC 40
# 1  CCSFS SLC 40
# 2  CCSFS SLC 40
# 3  CCSFS SLC 40
# 4  CCSFS SLC 40

# %% [markdown]
# ### Ejercicio 3
#
# ##### Mustra el la masa total transportada por los lanzamientos realizados donde el cliente es NASA (CRS)

# %%
query = """select PayloadMass, Customers 

from SPACEXTBL 
where Customers like 'N%'
limit 5   """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    PayloadMass            Customers
# 0        525.0  N,A,S,A,(,C,O,T,S,)
# 1        677.0  N,A,S,A, ,(,C,R,S,)
# 2       2296.0  N,A,S,A, ,(,C,R,S,)
# 3       2216.0  N,A,S,A, ,(,C,R,S,)
# 4       2395.0  N,A,S,A, ,(,C,R,S,)

# %%
dataset_part_2
# Out:
#      FlightNumber        Date BoosterVersion  PayloadMass  \
# 0               1  2010-06-04       Falcon 9   8191.07911
# 1               2  2012-05-22       Falcon 9    525.00000
# 2               3  2013-03-01       Falcon 9    677.00000
# 3               4  2013-09-29       Falcon 9    500.00000
# 4               5  2013-12-03       Falcon 9   3170.00000
# ..            ...         ...            ...          ...
# 163           164  2022-08-28       Falcon 9  13260.00000
# 164           165  2022-08-31       Falcon 9  13260.00000
# 165           166  2022-09-17       Falcon 9  13260.00000
# 166           167  2022-09-24       Falcon 9  13260.00000
# 167           168  2022-10-05       Falcon 9   8191.07911
#
#                        Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0    Dragon Qualification Unit   LEO  CCSFS SLC 40      None None        1
# 1           COTS Demo Flight 2   LEO  CCSFS SLC 40      None None        1
# 2                        CRS-2   ISS  CCSFS SLC 40      None None        1
# 3                     CASSIOPE    PO   VAFB SLC 4E    False Ocean        1
# 4                        SES-8   GTO  CCSFS SLC 40      None None        1
# ..                         ...   ...           ...            ...      ...
# 163       Starlink 4-23 (v1.5)  VLEO    KSC LC 39A      True ASDS        2
# 164        Starlink 3-4 (v1.5)  VLEO   VAFB SLC 4E      True ASDS        7
# 165       Starlink 4-34 (v1.5)  VLEO  CCSFS SLC 40      True ASDS        6
# 166       Starlink 4-35 (v1.5)  VLEO  CCSFS SLC 40      True ASDS        4
# 167                     Crew-5   ISS    KSC LC 39A      True ASDS        1
#
#      GridFins  Reused   Legs                LandingPad  Block  \
# 0       False   False  False                       NaN      1
# 1       False   False  False                       NaN      1
# 2       False   False  False                       NaN      1
# 3       False   False  False                       NaN      1
# 4       False   False  False                       NaN      1
# ..        ...     ...    ...                       ...    ...
# 163      True    True   True  5e9e3033383ecb075134e7cd      5
# 164      True    True   True  5e9e3032383ecb6bb234e7ca      5
# 165      True    True   True  5e9e3033383ecbb9e534e7cc      5
# 166      True    True   True  5e9e3033383ecbb9e534e7cc      5
# 167      True   False   True  5e9e3033383ecbb9e534e7cc      5
#
#                      Customers Mission_Outcome  ReusedCount Serial  \
# 0                  S,p,a,c,e,X            True            0  B0003
# 1          N,A,S,A,(,C,O,T,S,)            True            0  B0005
# 2          N,A,S,A, ,(,C,R,S,)            True            0  B0007
# 3                        M,D,A            True            0  B1003
# 4                        S,E,S            True            0  B1004
# ..                         ...             ...          ...    ...
# 163                S,p,a,c,e,X            True            1  B1069
# 164                S,p,a,c,e,X            True            6  B1063
# 165                S,p,a,c,e,X            True            5  B1067
# 166                S,p,a,c,e,X            True            0  B1072
# 167  N,A,S,A, ,(,C,C,t,C,a,p,)            True            0  B1077
#
#       Longitude   Latitude  Class
# 0    -80.577366  28.561857      0
# 1    -80.577366  28.561857      0
# 2    -80.577366  28.561857      0
# 3   -120.610829  34.632093      0
# 4    -80.577366  28.561857      0
# ..          ...        ...    ...
# 163  -80.603956  28.608058      1
# 164 -120.610829  34.632093      1
# 165  -80.577366  28.561857      1
# 166  -80.577366  28.561857      1
# 167  -80.603956  28.608058      1
#
# [168 rows x 21 columns]

# %% [markdown]
# ### Ejercicio 4
#
# ##### Muestra la masa media tranportada por lanzamientos con serie que comienza por B1

# %%
query = """select avg(PayloadMass), Customers, Serial 

from SPACEXTBL 
where Serial like 'B1%' 
Group by Serial

Limit 8
  """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    avg(PayloadMass)            Customers Serial
# 0             500.0                M,D,A  B1003
# 1            3170.0                S,E,S  B1004
# 2            3325.0        T,h,a,i,c,o,m  B1005
# 3            2296.0  N,A,S,A, ,(,C,R,S,)  B1006
# 4            1316.0        O,r,b,c,o,m,m  B1007
# 5            4535.0        A,s,i,a,S,a,t  B1008
# 6            2216.0  N,A,S,A, ,(,C,R,S,)  B1010
# 7            4428.0        A,s,i,a,S,a,t  B1011

# %% [markdown]
# ### Ejercicio 5
#
# ##### Muestra la fecha donde se realizo el primer aterrizaje exitoso sobre terreno (TRUE RTLS)
#
# *Pista:Utiliza la función min*

# %%
query = """select min(date) 

from SPACEXTBL 
where LandingOutcome = 'TRUE RTLS' 


  """
df  = pd.read_sql(query, con = engine )
df
# Out:
#     min(date)
# 0  2015-12-22

# %%
dataset_part_2
# Out:
#      FlightNumber        Date BoosterVersion  PayloadMass  \
# 0               1  2010-06-04       Falcon 9   8191.07911
# 1               2  2012-05-22       Falcon 9    525.00000
# 2               3  2013-03-01       Falcon 9    677.00000
# 3               4  2013-09-29       Falcon 9    500.00000
# 4               5  2013-12-03       Falcon 9   3170.00000
# ..            ...         ...            ...          ...
# 163           164  2022-08-28       Falcon 9  13260.00000
# 164           165  2022-08-31       Falcon 9  13260.00000
# 165           166  2022-09-17       Falcon 9  13260.00000
# 166           167  2022-09-24       Falcon 9  13260.00000
# 167           168  2022-10-05       Falcon 9   8191.07911
#
#                        Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0    Dragon Qualification Unit   LEO  CCSFS SLC 40      None None        1
# 1           COTS Demo Flight 2   LEO  CCSFS SLC 40      None None        1
# 2                        CRS-2   ISS  CCSFS SLC 40      None None        1
# 3                     CASSIOPE    PO   VAFB SLC 4E    False Ocean        1
# 4                        SES-8   GTO  CCSFS SLC 40      None None        1
# ..                         ...   ...           ...            ...      ...
# 163       Starlink 4-23 (v1.5)  VLEO    KSC LC 39A      True ASDS        2
# 164        Starlink 3-4 (v1.5)  VLEO   VAFB SLC 4E      True ASDS        7
# 165       Starlink 4-34 (v1.5)  VLEO  CCSFS SLC 40      True ASDS        6
# 166       Starlink 4-35 (v1.5)  VLEO  CCSFS SLC 40      True ASDS        4
# 167                     Crew-5   ISS    KSC LC 39A      True ASDS        1
#
#      GridFins  Reused   Legs                LandingPad  Block  \
# 0       False   False  False                       NaN      1
# 1       False   False  False                       NaN      1
# 2       False   False  False                       NaN      1
# 3       False   False  False                       NaN      1
# 4       False   False  False                       NaN      1
# ..        ...     ...    ...                       ...    ...
# 163      True    True   True  5e9e3033383ecb075134e7cd      5
# 164      True    True   True  5e9e3032383ecb6bb234e7ca      5
# 165      True    True   True  5e9e3033383ecbb9e534e7cc      5
# 166      True    True   True  5e9e3033383ecbb9e534e7cc      5
# 167      True   False   True  5e9e3033383ecbb9e534e7cc      5
#
#                      Customers Mission_Outcome  ReusedCount Serial  \
# 0                  S,p,a,c,e,X            True            0  B0003
# 1          N,A,S,A,(,C,O,T,S,)            True            0  B0005
# 2          N,A,S,A, ,(,C,R,S,)            True            0  B0007
# 3                        M,D,A            True            0  B1003
# 4                        S,E,S            True            0  B1004
# ..                         ...             ...          ...    ...
# 163                S,p,a,c,e,X            True            1  B1069
# 164                S,p,a,c,e,X            True            6  B1063
# 165                S,p,a,c,e,X            True            5  B1067
# 166                S,p,a,c,e,X            True            0  B1072
# 167  N,A,S,A, ,(,C,C,t,C,a,p,)            True            0  B1077
#
#       Longitude   Latitude  Class
# 0    -80.577366  28.561857      0
# 1    -80.577366  28.561857      0
# 2    -80.577366  28.561857      0
# 3   -120.610829  34.632093      0
# 4    -80.577366  28.561857      0
# ..          ...        ...    ...
# 163  -80.603956  28.608058      1
# 164 -120.610829  34.632093      1
# 165  -80.577366  28.561857      1
# 166  -80.577366  28.561857      1
# 167  -80.603956  28.608058      1
#
# [168 rows x 21 columns]

# %%
set(dataset_part_2["Mission_Outcome"].to_list())
# Out:
# {False, True}

# %% [markdown]
# ### Ejercicio 6
#
# ##### Muestra las series de los cohetes que aterrizaron sobre portaviones (TRUE ASDS) con una masa entre 4000 y 6000

# %%
query = """select Serial, LandingOutcome, PayloadMass    

from SPACEXTBL 
where LandingOutcome = 'TRUE ASDS' and PayloadMass BETWEEN 4000 and 6000 


  """
df  = pd.read_sql(query, con = engine )
df
# Out:
#   Serial LandingOutcome  PayloadMass
# 0  B1022      True ASDS       4696.0
# 1  B1026      True ASDS       4600.0
# 2  B1021      True ASDS       5300.0
# 3  B1031      True ASDS       5200.0
# 4  B1046      True ASDS       5800.0
# 5  B1046      True ASDS       4000.0
# 6  B1059      True ASDS       5000.0

# %% [markdown]
# ### Ejercicio 7
#
# ##### Muestra el numero de lanzamientos que completaron su mision correctamente y aquellos que fallaron

# %%
query = """select count(Mission_Outcome)    

from SPACEXTBL 



Group By Mission_Outcome


  """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    count(Mission_Outcome)
# 0                       2
# 1                      88

# %% [markdown]
# ### Ejercicio 8
#
# ##### Muestra las series de los cohetes que transportaron la masa máxima

# %%
query = """select Serial, LandingOutcome, PayloadMass   

from SPACEXTBL 

WHERE PayloadMass = (select max(PayloadMass) from SPACEXTBL);




  """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    Serial LandingOutcome  PayloadMass
# 0   B1048      True ASDS      15600.0
# 1   B1049      True ASDS      15600.0
# 2   B1051      True ASDS      15600.0
# 3   B1056     False ASDS      15600.0
# 4   B1048     False ASDS      15600.0
# 5   B1051      True ASDS      15600.0
# 6   B1049      True ASDS      15600.0
# 7   B1059      True ASDS      15600.0
# 8   B1049      True ASDS      15600.0
# 9   B1060      True ASDS      15600.0
# 10  B1058      True ASDS      15600.0
# 11  B1051      True ASDS      15600.0
# 12  B1060      True ASDS      15600.0

# %%
dataset_part_2
# Out:
#     FlightNumber        Date BoosterVersion   PayloadMass  \
# 0              1  2010-06-04       Falcon 9   6123.547647
# 1              2  2012-05-22       Falcon 9    525.000000
# 2              3  2013-03-01       Falcon 9    677.000000
# 3              4  2013-09-29       Falcon 9    500.000000
# 4              5  2013-12-03       Falcon 9   3170.000000
# ..           ...         ...            ...           ...
# 85            86  2020-09-03       Falcon 9  15600.000000
# 86            87  2020-10-06       Falcon 9  15600.000000
# 87            88  2020-10-18       Falcon 9  15600.000000
# 88            89  2020-10-24       Falcon 9  15600.000000
# 89            90  2020-11-05       Falcon 9   3681.000000
#
#                       Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0   Dragon Qualification Unit   LEO  CCSFS SLC 40      None None        1
# 1          COTS Demo Flight 2   LEO  CCSFS SLC 40      None None        1
# 2                       CRS-2   ISS  CCSFS SLC 40      None None        1
# 3                    CASSIOPE    PO   VAFB SLC 4E    False Ocean        1
# 4                       SES-8   GTO  CCSFS SLC 40      None None        1
# ..                        ...   ...           ...            ...      ...
# 85                Starlink-11  VLEO    KSC LC 39A      True ASDS        2
# 86                Starlink-12  VLEO    KSC LC 39A      True ASDS        3
# 87                Starlink-13  VLEO    KSC LC 39A      True ASDS        6
# 88                Starlink-14  VLEO  CCSFS SLC 40      True ASDS        3
# 89   GPS III SV04 (Sacagawea)   MEO  CCSFS SLC 40      True ASDS        1
#
#     GridFins  Reused   Legs                LandingPad  Block  \
# 0      False   False  False                       NaN    1.0
# 1      False   False  False                       NaN    1.0
# 2      False   False  False                       NaN    1.0
# 3      False   False  False                       NaN    1.0
# 4      False   False  False                       NaN    1.0
# ..       ...     ...    ...                       ...    ...
# 85      True    True   True  5e9e3032383ecb6bb234e7ca    5.0
# 86      True    True   True  5e9e3032383ecb6bb234e7ca    5.0
# 87      True    True   True  5e9e3032383ecb6bb234e7ca    5.0
# 88      True    True   True  5e9e3033383ecbb9e534e7cc    5.0
# 89      True   False   True  5e9e3032383ecb6bb234e7ca    5.0
#
#                     Customers  Mission_Outcome  ReusedCount Serial  \
# 0                      SpaceX             True            0  B0003
# 1                  NASA(COTS)             True            0  B0005
# 2                  NASA (CRS)             True            0  B0007
# 3                         MDA             True            0  B1003
# 4                         SES             True            0  B1004
# ..                        ...              ...          ...    ...
# 85                     SpaceX             True           12  B1060
# 86                     SpaceX             True           13  B1058
# 87                     SpaceX             True           12  B1051
# 88                     SpaceX             True           12  B1060
# 89  United States Space Force             True            8  B1062
#
#      Longitude   Latitude  Class
# 0   -80.577366  28.561857      0
# 1   -80.577366  28.561857      0
# 2   -80.577366  28.561857      0
# 3  -120.610829  34.632093      0
# 4   -80.577366  28.561857      0
# ..         ...        ...    ...
# 85  -80.603956  28.608058      1
# 86  -80.603956  28.608058      1
# 87  -80.603956  28.608058      1
# 88  -80.577366  28.561857      1
# 89  -80.577366  28.561857      1
#
# [90 rows x 21 columns]

# %% [markdown]
# ### Ejercicio 9
#
# ##### Muestra los el resultados del aterrizaje, la serie del cohete y las plataforma de lanzamiento de aquellos lanzamientos fallidos o no intentados en el año 2015

# %%
query = """select Serial, LandingOutcome, PayloadMass, LaunchSite   

from SPACEXTBL 

WHERE Date = '2015' AND Mission_Outcome like 'False' or 'NaN'

Group By Date




  """

# %% [markdown]
# ### Ejercicio 10
#
# ##### Muestra los resultados y la frecuencia de estos resultados entre 2010-06-04 y 2017-03-20 ordenados en orden descendiente según la frecuencia
